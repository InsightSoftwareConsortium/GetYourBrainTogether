# %% [markdown]
# ## Specimen and Image Metadata
#
# Specimen metadata for the fMOST dataset can be found at the [Allen Brain Map Data Catalog](https://knowledge.brain-map.org/data/K1YP17A0QIKJOMOAIS4/specimens). A snapshot has been downloaded and included with this tutorial.

# %%
# Install notebook dependencies
import sys

#!{sys.executable} -m pip install pandas

# %%
# Import notebook dependencies
import os
import pandas as pd

# %%
files = {}
files['specimen_metadata'] = './K1YP17A0QIKJOMOAIS4_specimen_metadata/SpecimenMetadata.csv'
files['specimen_manifest'] = './K1YP17A0QIKJOMOAIS4_specimen_manifest/SpecimenManifest.csv'
files['image_information'] = './image_metadata/hust_image_information.csv'

metadata = {}
for f in files:
    metadata[f] = pd.read_csv( files[f] )

# %% [markdown]
# # Specimen Metadata
#
# - Project ID: BICCN project identifier
# - Specimen ID: Brain specimen identifier
# - Specimen Type: Type of the specimen
# - Species: Species of the subject
# - Subject ID: Subject (organism) identifier
# - Age: Age of the subject at time of specimen collection in postnatal weeks
# - Sex: Sex of the subject
# - Genotype: Genotype of the subject

# %%
metadata['specimen_metadata'].head()
# Out:
#             Project ID            Specimen ID Specimen Type Species  \
# 0  K1YP17A0QIKJOMOAIS4  mouseID_497523_196469   whole brain   mouse
# 1  K1YP17A0QIKJOMOAIS4  mouseID_481967_194077   whole brain   mouse
# 2  K1YP17A0QIKJOMOAIS4  mouseID_491994_196472   whole brain   mouse
# 3  K1YP17A0QIKJOMOAIS4  mouseID_443055_191805   whole brain   mouse
# 4  K1YP17A0QIKJOMOAIS4  mouseID_512894_201605   whole brain   mouse
#
#    Subject ID  Age (postnatal weeks)     Sex  \
# 0      497523                     11  female
# 1      481967                     11    male
# 2      491994                     16  female
# 3      443055                      9    male
# 4      512894                     10    male
#
#                                             Genotype Subspecimen Type  \
# 0     Calb2-CreERT2/wt;Ai166(TIT2L-MORF-ICL-tTA2)/wt   reconstruction
# 1      Plxnd1-CreER/wt;Ai166(TIT2L-MORF-ICL-tTA2)/wt   reconstruction
# 2  Pdyn-T2A-CreERT2/wt;Ai166(TIT2L-MORF-ICL-tTA2)/wt   reconstruction
# 3     Dbh-Cre_KH212/wt;Ai166(TIT2L-MORF-ICL-tTA2)/wt   reconstruction
# 4  Pdyn-T2A-CreERT2/wt;Ai166(TIT2L-MORF-ICL-tTA2)/wt   reconstruction
#
#    Total Processed Subspecimens  Anatomical Structure
# 0                             0                   NaN
# 1                             0                   NaN
# 2                             0                   NaN
# 3                             0                   NaN
# 4                             0                   NaN

# %% [markdown]
# ## Specimen Manifest
#
# - Project ID: BICCN project indentifier
# - Specimen ID: Brain specimen identifier
# - File Name: Location of the primary high resolution image directory for the dataset

# %%
metadata['specimen_manifest'].head()
# Out:
#             Project ID            Specimen ID  \
# 0  K1YP17A0QIKJOMOAIS4  mouseID_511266_201604
# 1  K1YP17A0QIKJOMOAIS4  mouseID_504501_201593
# 2  K1YP17A0QIKJOMOAIS4  mouseID_501053_201591
# 3  K1YP17A0QIKJOMOAIS4  mouseID_439309_191798
# 4  K1YP17A0QIKJOMOAIS4  mouseID_454924_192335
#
#                                            File Name  Checksum  File Type  \
# 0  https://download.brainimagelibrary.org/43/48/4...       NaN  directory
# 1  https://download.brainimagelibrary.org/43/48/4...       NaN  directory
# 2  https://download.brainimagelibrary.org/43/48/4...       NaN  directory
# 3  https://download.brainimagelibrary.org/43/48/4...       NaN  directory
# 4  https://download.brainimagelibrary.org/43/48/4...       NaN  directory
#
#   Archive                                        Archive URI
# 0     BIL  https://download.brainimagelibrary.org/biccn/z...
# 1     BIL  https://download.brainimagelibrary.org/biccn/z...
# 2     BIL  https://download.brainimagelibrary.org/biccn/z...
# 3     BIL  https://download.brainimagelibrary.org/biccn/z...
# 4     BIL  https://download.brainimagelibrary.org/biccn/z...

# %% [markdown]
# ## Image Metadata
#
# - specimen_id : Brain specimen identifier
# - primary_image_x_size : Size of primary high resolution images in the x dimension
# - primary_image_y_size : Size of primary high resolution images in the y dimension
# - primary_image_z_Size : Number of primary high resolution images
# - orientation : Orientation of the high resolution images
# - primary_x_resolution : Resolution of primary high resolution images in the x dimension in micrometers
# - primary_y_resolution : Resolution of primary high resolution images in the y dimension in micrometers
# - primary_z_resolution : Spacing between primary high resolution images in micrometers
# - x_axis : Anatomical direction of the x axis
# - y_axis : Anatomical direction of the y axis
# - z_axis : Anatomical direction of the z axis
# - downsampled_red_method : Downsampling method use to create downsampled red channed volume
# - downsampled_red_volume_path : File name/path of the downsampled red channel volume
# - downsample_image_x_size : Size of the downsampled volume in the x dimension dimension
# - downsample_image_y_size : Size of the downsampled volume in the y dimension dimension
# - downsample_image_z_size : Size of the downsampled volume in the z dimension dimension
# - downsample_x_resolution : Resolution of downsample volume in the x dimension in micrometers
# - downsample_y_resolution : Resolution of downsample volume in the y dimension in micrometers
# - downsample_z_resolution : Resolution of downsample volume in the z dimension in micrometers
# - downsample_x_origin : The x physical coordinate of the first voxel
# - downsample_y_origin : The y physical coordinate of the first voxel
# - downsample_z_origin : The z physical coordinate of the first voxel

# %%
metadata['image_information'].head()
# Out:
#    Unnamed: 0           specimen_id  primary_image_x_size  \
# 0           0  mouseID_210254_15257                 21168
# 1           1  mouseID_297974_17109                 22793
# 2           2  mouseID_321237_17302                 34412
# 3           3  mouseID_344548_17542                 34748
# 4           4  mouseID_321244_17545                 35989
#
#    primary_image_y_size  primary_image_z_size orientation  \
# 0                 36400                 10252         IRA
# 1                 35000                 10553         SLA
# 2                 54600                  9847         IRA
# 3                 54600                 11333         IRA
# 4                 54600                 10750         IRA
#
#    primary_x_resolution  primary_y_resolution  primary_z_resolution  \
# 0                   0.3                   0.3                     1
# 1                   0.3                   0.3                     1
# 2                   0.2                   0.2                     1
# 3                   0.2                   0.2                     1
# 4                   0.2                   0.2                     1
#
#                  x_axis  ... downsampled_red_volume_path  \
# 0  inferior-to-superior  ...     15257_red_mm_IRA.nii.gz
# 1  superior-to-inferior  ...     17109_red_mm_SLA.nii.gz
# 2  inferior-to-superior  ...     17302_red_mm_IRA.nii.gz
# 3  inferior-to-superior  ...     17542_red_mm_IRA.nii.gz
# 4  inferior-to-superior  ...     17545_red_mm_IRA.nii.gz
#
#   downsample_image_x_size downsample_image_y_size downsample_image_z_size  \
# 0                     661                    1137                    1278
# 1                     712                    1094                    1319
# 2                    1075                    1706                    1230
# 3                    1086                    1706                    1416
# 4                    1124                    1706                    1343
#
#    downsample_x_resolution  downsample_y_resolution  downsample_z_resolution  \
# 0                      9.6                      9.6                      8.0
# 1                      9.6                      9.6                      8.0
# 2                      6.4                      6.4                      8.0
# 3                      6.4                      6.4                      8.0
# 4                      6.4                      6.4                      8.0
#
#    downsample_x_origin  downsample_y_origin  downsample_z_origin
# 0               0.0000                  0.0               0.0000
# 1              10.4928                  0.0               6.8256
# 2               0.0000                  0.0               0.0000
# 3               0.0000                  0.0               0.0000
# 4               0.0000                  0.0               0.0000
#
# [5 rows x 23 columns]
